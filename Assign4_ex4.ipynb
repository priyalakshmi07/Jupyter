# %%
import pandas as pd

Match_details=pd.read_csv(r'C:\Users\priyalakshmi\Desktop\PyFE\priyalakshmi01\matches.csv')#reading csv file using read_csv()

Match_details.head()#To display first 5 rows of a file
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
Match_details.columns.tolist()  #To display list of columns
# Out:
# ['id',
#  'season',
#  'city',
#  'date',
#  'team1',
#  'team2',
#  'toss_winner',
#  'toss_decision',
#  'result',
#  'dl_applied',
#  'winner',
#  'win_by_runs',
#  'win_by_wickets',
#  'player_of_match',
#  'venue',
#  'umpire1',
#  'umpire2',
#  'umpire3']

# %%
Non_zero_df = (Match_details['win_by_wickets'].loc[Match_details['win_by_wickets'] != 0]) # cerating dataframe for non-zero values of win_by_wicktes
Non_zero_df
# Out:
# 1       7
# 2      10
# 3       6
# 5       9
# 6       4
#        ..
# 684     6
# 689     5
# 691     5
# 692     2
# 695     8
# Name: win_by_wickets, Length: 371, dtype: int64

# %%
Median = (Match_details['win_by_wickets'].loc[Match_details['win_by_wickets'] != 0]).median()
# calculating the median of win_by_wickets
Median
# Out:
# 6.0

# %%
mean = (Match_details['win_by_wickets'].loc[Match_details['win_by_wickets'] != 0]).mean()
# calculating the mean of win_by_wickets

mean
# Out:
# 6.283018867924528

# %%
std = (Match_details['win_by_wickets'].loc[Match_details['win_by_wickets'] != 0]).std()
# calculating the std of win_by_wickets

std
# Out:
# 1.8375093446115944

# %%
group = Match_details.groupby(['city', 'winner'])
group.first()
# Out:
#                                         id  season        date  \
# city          winner
# Abu Dhabi     Chennai Super Kings      465    2014  2014-04-21
#               Kings XI Punjab          460    2014  2014-04-18
#               Kolkata Knight Riders    458    2014  2014-04-16
#               Rajasthan Royals         461    2014  2014-04-18
# Ahmedabad     Delhi Daredevils         180    2010  2010-03-15
# ...                                    ...     ...         ...
# Visakhapatnam Kings XI Punjab          619    2016  2016-05-13
#               Mumbai Indians           316    2012  2012-04-09
#               Rajasthan Royals         529    2015  2015-04-16
#               Rising Pune Supergiants  625    2016  2016-05-17
#               Sunrisers Hyderabad      537    2015  2015-04-22
#
#                                                        team1  \
# city          winner
# Abu Dhabi     Chennai Super Kings        Chennai Super Kings
# ...

# %%
Venue = (Match_details['city'].value_counts()['Mumbai'])
#calculating the total matches played at mumbai

mumbai_won=(Match_details['winner'].value_counts()['Mumbai Indians'])
#calculating the occurance of mumbai winning

probablity_of_winning = mumbai_won/Venue
#Venue/calclulating the probablity of mumbai winning i.e Total matches won/total matches played at mumbai

probablity_of_winning
# Out:
# 1.0425531914893618
